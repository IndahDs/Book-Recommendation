# %% [markdown]
# # **Sistem rekomendasi buku berdasarkan preferensi pengguna dan rating yang diberikan pengguna sebelumnya**

# %% [markdown]
# # **1. Mengimpor pustaka/modul python yang dibutuhkan**

# %%
# Library ini merupakan salah satu perkembangan scikit-learn yang berfokus pada pembangunan dan analisa sistem rekomendasi
# !pip install surprise
# Out:
# Collecting surprise
#   Downloading surprise-0.1-py2.py3-none-any.whl (1.8 kB)
# Collecting scikit-surprise
#   Downloading scikit-surprise-1.1.1.tar.gz (11.8 MB)
#      |████████████████████████████████| 11.8 MB 5.6 MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-surprise->surprise) (1.1.0)
# Requirement already satisfied: numpy>=1.11.2 in /usr/local/lib/python3.7/dist-packages (from scikit-surprise->surprise) (1.21.6)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-surprise->surprise) (1.4.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from scikit-surprise->surprise) (1.15.0)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (setup.py) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.1-cp37-cp37m-linux_x86_64.whl size=1630185 sha256=e998752b21f7773c2e72cc8fbb8caa881fcc3590ebc4f61286f4238d182114a6
#   Stored in directory: /root/.cache/pip/wheels/76/44/74/b498c42be47b2406bd27994e16c5188e337c657025ab400c1c
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise, surprise
# Successfully installed scikit-surprise-1.1.1 surprise-0.1

# %%
# Libraries for data preparation & visualization
import numpy as np
import pandas as pd
import gzip
import seaborn as sns
import re
import random
import zipfile,os
# Ignore printing warnings for general readability
import warnings 
warnings.filterwarnings("ignore")

# Importing libraries for model building & evaluation
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from surprise import Reader, Dataset, SVD
from surprise.model_selection import train_test_split, cross_validate, GridSearchCV
from surprise import accuracy

# %% [markdown]
# ### **1.1 Menyiapkan kredensial akun Kaggle**

# %%
# Membuat folder .kaggle di dalam folder root
# !rm -rf ~/.kaggle && mkdir ~/.kaggle/

# Menyalin berkas kaggle.json pada direktori aktif saat ini ke folder .kaggle
# !mv kaggle.json ~/.kaggle/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# ## **1.2 Mengunduh dan Menyiapkan Dataset**

# %%
# Mengunduh dataset menggunakan Kaggle CLI
# !kaggle datasets download -d arashnic/book-recommendation-dataset
# Out:
# Downloading book-recommendation-dataset.zip to /content
#  84% 20.0M/23.8M [00:00<00:00, 90.0MB/s]
# 100% 23.8M/23.8M [00:00<00:00, 91.0MB/s]

# %%
# Mengekstrak berkas zip ke direktori aktif saat ini
# !unzip /content/book-recommendation-dataset.zip
# Out:
# Archive:  /content/book-recommendation-dataset.zip
#   inflating: Books.csv
#   inflating: Ratings.csv
#   inflating: Users.csv

# %% [markdown]
# # **3. Pemahaman Data (*Data Understanding*)**

# %% [markdown]
# ## **3.2 *Exploratory Data Analysis* (EDA)**

# %% [markdown]
# ### **3.2.1 Books**
#
# karakteristik data buku

# %%
books = pd.read_csv('Books.csv')
books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# 1       Richard Bruce Wright                2001
# 2               Carlo D'Este                1991
# 3           Gina Bari Kolata                1999
# 4            E. J. W. Barber                1999
# ...                      ...                 ...
# 271355        Paula Danziger                1988
# 271356            Teri Sloat                1991
# 271357      Christine Wicker                2004
# 271358                 Plato                1996
# 271359   Christopher  Biffle                2000
#
#                                                Publisher  \
# 0                                Oxford University Press
# 1                                  HarperFlamingo Canada
# 2                                        HarperPerennial
# 3                                   Farrar Straus Giroux
# 4                             W. W. Norton &amp; Company
# ...                                                  ...
# 271355                   Random House Childrens Pub (Mm)
# 271356                                      Dutton Books
# 271357                                HarperSanFrancisco
# 271358                           Oxford University Press
# 271359  McGraw-Hill Humanities/Social Sciences/Languages
#
#                                               Image-URL-S  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-M  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-L
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
# [271360 rows x 8 columns]

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271359 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB

# %%
print('Total ISBN:', len(books.ISBN.unique()))
print('Total judul:', len(books['Book-Title'].unique()))
print('Total pengarang:', len(books['Book-Author'].unique()))
print('Total penerbit:', len(books['Publisher'].unique()))
# Out:
# Total ISBN: 271360
# Total judul: 242135
# Total pengarang: 102024
# Total penerbit: 16808

# %% [markdown]
# ### **3.2.2 Rating**
#
# karakteristik data rating

# %%
ratings = pd.read_csv('Ratings.csv')
ratings
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1149780 non-null  int64
#  1   ISBN         1149780 non-null  object
#  2   Book-Rating  1149780 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 26.3+ MB

# %%
ratings['Book-Rating'].describe().T
# Out:
# count    1.149780e+06
# mean     2.866950e+00
# std      3.854184e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      7.000000e+00
# max      1.000000e+01
# Name: Book-Rating, dtype: float64

# %%
print('Total pengguna:', len(ratings['User-ID'].unique()))
print('Total buku:', len(ratings['ISBN'].unique()))
print('Total rating yang diterima:', len(ratings))
# Out:
# Total pengguna: 105283
# Total buku: 340556
# Total rating yang diterima: 1149780

# %%
# plot
with sns.axes_style('darkgrid'):
    g = sns.catplot("Book-Rating", data=ratings, aspect=2.0, kind='count')
    g.set_ylabels("Jumlah total peringkat")

# %% [markdown]
# banyak buku yang masih memiliki rating 0, maka data tersebut dapat dihapus dengan tujuan mengurangi bias pada proses analisis

# %% [markdown]
# ### **3.2.3 Users**
#
# karakteristik data user

# %%
users = pd.read_csv('Users.csv')
users
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %% [markdown]
# Perlu dilakukan handling missing value pada kolom age dalam proses data preparation.

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278858 entries, 0 to 278857
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   User-ID   278858 non-null  int64
#  1   Location  278858 non-null  object
#  2   Age       168096 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.4+ MB

# %% [markdown]
# # **4. Persiapan Data (*Data Preparation*)**

# %% [markdown]
# ### **4.1 Books**
#
# menyeleksi fitur yang diperlukan

# %%
buku = books[['ISBN', 'Book-Title','Book-Author', 'Publisher']]
buku.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author                   Publisher
# 0    Mark P. O. Morford     Oxford University Press
# 1  Richard Bruce Wright       HarperFlamingo Canada
# 2          Carlo D'Este             HarperPerennial
# 3      Gina Bari Kolata        Farrar Straus Giroux
# 4       E. J. W. Barber  W. W. Norton &amp; Company

# %%
# cek missing value
buku.isnull().sum()
# Out:
# ISBN           0
# Book-Title     0
# Book-Author    1
# Publisher      2
# dtype: int64

# %%
# mengisi data kosong pada publisher dan author
buku.loc[:,'Book-Author'] = buku['Book-Author'].fillna('Unknown')
buku.loc[:,'Publisher'] = buku['Publisher'].fillna('Unknown')
buku.isnull().sum()
# Out:
# ISBN           0
# Book-Title     0
# Book-Author    0
# Publisher      0
# dtype: int64

# %% [markdown]
# ### **4.2 Ratings**
#
# menyeleksi fitur yang diperlukan

# %%
rating = ratings
rating.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
print('Jumlah rating 0 :', rating['Book-Rating'].eq(0).sum())
rating.shape
# Out:
# Jumlah rating 0 : 716109
# (1149780, 3)

# %%
# menghapus data rating 0

rating = rating[ratings['Book-Rating']>0]
rating.shape
# Out:
# (433671, 3)

# %%
# plot
with sns.axes_style('darkgrid'):
    g = sns.catplot("Book-Rating", data=ratings, aspect=1.5, kind='count')
    g.set_ylabels("Total number of ratings")

# %% [markdown]
# ### **4.2 Users**
#
# menyeleksi fitur yang diperlukan

# %%
user = users
user.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
# mengisi missing value dengan moduse dari Age
user['Age'] = user['Age'].fillna(user['Age'].mode())
user.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110761
# dtype: int64

# %%
user['Age'].hist(bins=100)

# %%
# menggabungkan data buku dan rating
rating_buku = pd.merge(rating, buku, on=['ISBN'],)
rating_buku.head()
# Out:
#    User-ID        ISBN  Book-Rating  \
# 0   276726  0155061224            5
# 1   276729  052165615X            3
# 2   276729  0521795028            6
# 3   276744  038550120X            7
# 4    11676  038550120X           10
#
#                                           Book-Title    Book-Author  \
# 0                                   Rites of Passage     Judith Rae
# 1                                     Help!: Level 1  Philip Prowse
# 2  The Amsterdam Connection : Level 4 (Cambridge ...    Sue Leather
# 3                                    A Painted House   JOHN GRISHAM
# 4                                    A Painted House   JOHN GRISHAM
#
#                     Publisher
# 0                      Heinle
# 1  Cambridge University Press
# 2  Cambridge University Press
# 3                   Doubleday
# 4                   Doubleday

# %% [markdown]
# # **5. Modelling**

# %% [markdown]
# ## **5.1 Popularity based recommendation**
#
# merekomendasikan buku paling populer berdasarkan rata rata rating dan jumlah rating yang diterima

# %% [markdown]
# ### **5.1.1 berdasarkan rata-rata rating**

# %%
rata_rating_buku = rating_buku.groupby('ISBN')['Book-Rating'].mean().sort_values(ascending=False)
rata_rating_buku
# Out:
# ISBN
# 034017420X    10.0
# 0821414534    10.0
# 0821225987    10.0
# 0821226665    10.0
# 0821226703    10.0
#               ...
# 1903933145     1.0
# 0324041594     1.0
# 0789725134     1.0
# 1857975065     1.0
# 0061082066     1.0
# Name: Book-Rating, Length: 149836, dtype: float64

# %% [markdown]
# terdapat lebih dari 20000 buku yang memiliki rating tertinggi, sehingga kita tidak bisa merekomendasikan 10 buku terbaik hanya berdasarkan rata-rata rating saja

# %%
rata_rating_buku.hist(bins=100)

# %%
rata_rating_buku.head(10).plot(kind='bar')

# %% [markdown]
# ### **5.1.2 berdasarkan jumlah peringkat yang diterima**
#
# # diperlukan informasi lain untuk merekomendasikan buku terbaik, disini akan digunakan jumlah rating yang diterima tiap buku

# %%
# recommend dari rating yang diterima
buku_populer = rating_buku.groupby('ISBN')['Book-Rating'].count().sort_values(ascending=False)
buku_populer
# Out:
# ISBN
# 0316666343    707
# 0971880107    581
# 0385504209    487
# 0312195516    383
# 0060928336    320
#              ...
# 0553100165      1
# 0553100130      1
# 0553099817      1
# 0553099809      1
# B000234N3A      1
# Name: Book-Rating, Length: 149836, dtype: int64

# %%
buku_populer.hist(bins=100)

# %%
buku_populer.head(10).sort_values().plot(kind='bar', title='Rating Terbanyak yang Diterima per Buku')

# %% [markdown]
# ### **5.1.3 Weighted rating**
#
#
# digunakan untuk menggabungkan kedua informasi yaitu berdasarkan rata-rata rating dan jumlah rating diterima, kemudian akan dipilih 10 produk

# %%
rekomen_populer = pd.concat([rata_rating_buku, buku_populer],
                                   axis=1, join='inner',
                                   keys=['Average Rating', 'Rating Received'])

# %%
v = rekomen_populer['Rating Received'] # jumlah rating diterima
R = rekomen_populer['Average Rating'] # rata-rata rating per produk
C = rekomen_populer['Average Rating'].mean() # rata-rata rating seluruh produk
m = rekomen_populer['Rating Received'].quantile(0.75) # minimal jumlah rating yang diterima

rekomen_populer['Weighted Rating'] = ((R*v)+(C*m))/(v+m)
rekomen_populer = rekomen_populer.sort_values('Weighted Rating', ascending=False)
rekomen_populer.head(10)
# Out:
#             Average Rating  Rating Received  Weighted Rating
# ISBN
# 0439425220        9.869565               23         9.682203
# 1888054557       10.000000               11         9.619622
# 0836213319        9.923077               13         9.603672
# 0618002235        9.720000               25         9.557596
# 0060256656        9.750000               20         9.547958
# 0394800893       10.000000                8         9.505509
# 0394800389        9.785714               14         9.503443
# 1571456988       10.000000                7         9.450565
# 089471838X       10.000000                7         9.450565
# 0836220889        9.583333               24         9.425196

# %%
# hasil rekomendasi

judul_populer = pd.merge(rekomen_populer, books[['ISBN', 'Book-Title']],
                         on='ISBN')
judul_populer = judul_populer[['Weighted Rating', 'Book-Title']]
judul_populer = judul_populer.drop_duplicates('Book-Title').set_index('Book-Title')
judul_populer.head(10)
# Out:
#                                                     Weighted Rating
# Book-Title
# Harry Potter and the Chamber of Secrets Postcar...         9.682203
# Postmarked Yesteryear: 30 Rare Holiday Postcards           9.619622
# Dilbert: A Book of Postcards                               9.603672
# The Two Towers (The Lord of the Rings, Part 2)             9.557596
# The Giving Tree                                            9.547958
# The Sneetches and Other Stories                            9.505509
# Fox in Socks (I Can Read It All by Myself Begin...         9.503443
# Uncle John's Supremely Satisfying Bathroom Read...         9.450565
# Natural California: A Postcard Book                        9.450565
# Calvin and Hobbes                                          9.425196

# %% [markdown]
# ## **5.2 Collaborative filtering (model based) recommendation**
#
# Merekomendasikan buku lain kepada user yang memberi rating buku

# %%
rating_user = rating_buku
rating_user
# Out:
#         User-ID        ISBN  Book-Rating  \
# 0        276726  0155061224            5
# 1        276729  052165615X            3
# 2        276729  0521795028            6
# 3        276744  038550120X            7
# 4         11676  038550120X           10
# ...         ...         ...          ...
# 383837   276688  0425156737            2
# 383838   276688  0671563149            6
# 383839   276688  1575660792            7
# 383840   276704  0380796155            5
# 383841   276704  0806917695            5
#
#                                                Book-Title       Book-Author  \
# 0                                        Rites of Passage        Judith Rae
# 1                                          Help!: Level 1     Philip Prowse
# 2       The Amsterdam Connection : Level 4 (Cambridge ...       Sue Leather
# 3                                         A Painted House      JOHN GRISHAM
# 4                                         A Painted House      JOHN GRISHAM
# ...                                                   ...               ...
# 383837                                      Graven Images   Jane Waterhouse
# 383838          MUDDY WATER (Peter Bartholomew Mysteries)     Sally Gunning
# 383839                                        Gray Matter   Shirley Kennett
# 383840                                       White Abacus  Damien Broderick
# 383841  Perplexing Lateral Thinking Puzzles: Scholasti...       Paul Sloane
#
#                                 Publisher
# 0                                  Heinle
# 1              Cambridge University Press
# 2              Cambridge University Press
# 3                               Doubleday
# 4                               Doubleday
# ...                                   ...
# 383837           Berkley Publishing Group
# 383838                             Pocket
# 383839  Kensington Publishing Corporation
# 383840                                Eos
# 383841                Sterling Publishing
#
# [383842 rows x 6 columns]

# %% [markdown]
# ### **Label encoding**
#
# encoder User ID dan Book Title

# %%
le = LabelEncoder()
rating_user['UserID'] = le.fit_transform(rating_user['User-ID'])
rating_user['TitleID'] = le.fit_transform(rating_user['Book-Title'])
rating_user.drop('User-ID', axis=1, inplace=True)
rating_user
# Out:
#               ISBN  Book-Rating  \
# 0       0155061224            5
# 1       052165615X            3
# 2       0521795028            6
# 3       038550120X            7
# 4       038550120X           10
# ...            ...          ...
# 383837  0425156737            2
# 383838  0671563149            6
# 383839  1575660792            7
# 383840  0380796155            5
# 383841  0806917695            5
#
#                                                Book-Title       Book-Author  \
# 0                                        Rites of Passage        Judith Rae
# 1                                          Help!: Level 1     Philip Prowse
# 2       The Amsterdam Connection : Level 4 (Cambridge ...       Sue Leather
# 3                                         A Painted House      JOHN GRISHAM
# 4                                         A Painted House      JOHN GRISHAM
# ...                                                   ...               ...
# 383837                                      Graven Images   Jane Waterhouse
# 383838          MUDDY WATER (Peter Bartholomew Mysteries)     Sally Gunning
# 383839                                        Gray Matter   Shirley Kennett
# 383840                                       White Abacus  Damien Broderick
# 383841  Perplexing Lateral Thinking Puzzles: Scholasti...       Paul Sloane
#
#                                 Publisher  UserID  TitleID
# 0                                  Heinle   67541    84140
# 1              Cambridge University Press   67542    46362
# 2              Cambridge University Press   67542    97833
# 3                               Doubleday   67543     3064
# 4                               Doubleday    2719     3064
# ...                                   ...     ...      ...
# 383837           Berkley Publishing Group   67537    43523
# 383838                             Pocket   67537    63876
# 383839  Kensington Publishing Corporation   67537    43547
# 383840                                Eos   67538   131513
# 383841                Sterling Publishing   67538    78101
#
# [383842 rows x 7 columns]

# %% [markdown]
# ## **6. Pengembangan Model**
#
# Mentraining data user buku dengan model SVD dari library surprise dan mengevaluasi dengan 10-fold cross validation menggunakan matriks RMSE dan MAE.
#
# Validasi silang 10 kali lipat akan melakukan prosedur pemasangan sebanyak sepuluh kali, dengan masing-masing pemasangan dilakukan pada set pelatihan yang terdiri dari 90% dari total set pelatihan yang dipilih secara acak, dengan 10% sisanya digunakan sebagai set penahan untuk validasi.
#
# 10 fold CV adalah salah satu K fold CV yang direkomendasikan untuk pemilihan model terbaik karena cenderung memberikan estimasi akurasi yang kurang bias dibandingkan dengan CV biasa, leave-one-out CV dan bootstrap.

# %%
reader = Reader(rating_scale=(1, 10))
data = Dataset.load_from_df(rating_user[['UserID', 'TitleID', 'Book-Rating']],
                            reader)
svd = SVD(verbose=False, n_epochs=10)
cross_validate(svd, data, measures=['RMSE', 'MAE'], cv=10, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 10 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Fold 6  Fold 7  Fold 8  Fold 9  Fold 10 Mean    Std
# RMSE (testset)    1.6307  1.6388  1.6393  1.6312  1.6371  1.6376  1.6414  1.6460  1.6372  1.6501  1.6389  0.0056
# MAE (testset)     1.2628  1.2686  1.2693  1.2609  1.2661  1.2675  1.2667  1.2706  1.2696  1.2733  1.2675  0.0035
# Fit time          13.54   12.89   17.73   12.81   13.00   12.86   12.94   12.92   12.73   13.13   13.45   1.44
# Test time         0.37    0.59    0.51    0.66    0.74    0.41    0.78    0.61    0.47    0.66    0.58    0.13
# {'fit_time': (13.536639213562012,
#   12.888691902160645,
#   17.730122566223145,
#   12.80651593208313,
#   12.997690439224243,
#   12.863590002059937,
#   12.940323829650879,
#   12.917957782745361,
#   12.733799457550049,
#   13.128747463226318),
#  'test_mae': array([1.26282593, 1.26856121, 1.26931319, 1.26086506, 1.26611039,
#         1.26745886, 1.26666355, 1.27058822, 1.26961388, 1.2733418 ]),
#  'test_rmse': array([1.63066978, 1.63876284, 1.63927667, 1.63115113, 1.63705437,
#         1.63757476, 1.64139446, 1.64599225, 1.63723657, 1.65008258]),
#  'test_time': (0.365429162979126,
#   0.5853135585784912,
#   0.5054576396942139,
#   0.6556687355041504,
#   0.742617130279541,
#   0.4127955436706543,
#   0.7764570713043213,
#   0.6143038272857666,
#   0.47205209732055664,
#   0.658301830291748)}

# %% [markdown]
# ## **Merekomendasikan buku berdasarkan riwayat rating user**
#
# prediksi rating buku dengan model SVD

# %%
def user_recommendation(userid):
    user = rating_user[['ISBN', 'Book-Title', 'Book-Author', 'Publisher', 'TitleID']]
    user = user.reset_index()
    # getting full dataset
    data = Dataset.load_from_df(rating_user[['UserID','TitleID','Book-Rating']], reader)
    trainset = data.build_full_trainset()
    svd.fit(trainset)
    user['Estimate_Score'] = user['TitleID'].apply(lambda x: svd.predict(userid, x).est)
    user = user.drop(['index','TitleID'], axis = 1)
    user = user.sort_values('Estimate_Score' , ascending = False)
    counts1 = user['Estimate_Score'].value_counts()
    user = user[user['Estimate_Score'].isin(counts1[counts1 == 1].index)]
    return user.head(10)

# %%
# mencari user yang menyukai buku David Copperfield sebagai contoh
rating_user[rating_user['Book-Title'].str.contains('David Copperfield')]
# Out:
#               ISBN  Book-Rating  \
# 118262  0140430083            3
# 118263  0140430083            8
# 118264  0140430083           10
# 127504  0192835785            6
# 149078  185326024X            5
# 149079  185326024X            5
# 149080  185326024X            8
# 149081  185326024X            8
# 149082  185326024X            7
# 149083  185326024X            6
# 149084  185326024X            8
# 149085  185326024X            8
# 149086  185326024X            5
# 153182  0140434941            1
# 153183  0140434941            8
# 153184  0140434941            9
# 153185  0140434941            8
# 153186  0140434941            8
# 153187  0140434941            8
# 153244  0061052280            8
# 153245  0061052280            6
# 153246  0061052280            8
# 173944  0812544048            5
# 201671  0451522923            7
# 201672  0451522923           10
# 201673  0451522923           10
# 201674  0451522923            7
# 211382  0553211897            8
# 211383  0553211897           10
# 241906  0679783415            9
# 241907  0679783415           10
# 241908  0679783415            5
# 262789  0140620265            5
# 262790  0140620265            8
# 262791  0140620265            8
# 268346  0393958280           10
# 268347  0393958280            7
# 286854  0451519078            9
# 286946  0061054925            7
# 286947  0061054925            5
# 288487  1569871183            7
# 312099  0460872362            7
# 316872  0192816098            5
# 319259  0671451065           10
# 321959  0679405712           10
# 356275  0061054933            3
# 365540  0553210513            7
# 376953  0866119744            5
#
#                                                Book-Title        Book-Author  \
# 118262  The Personal History of David Copperfield (Pen...    Charles Dickens
# 118263  The Personal History of David Copperfield (Pen...    Charles Dickens
# 118264  The Personal History of David Copperfield (Pen...    Charles Dickens
# 127504        David Copperfield (Oxford World's Classics)    Charles Dickens
# 149078            David Copperfield (Wordsworth Classics)    Charles Dickens
# 149079            David Copperfield (Wordsworth Classics)    Charles Dickens
# 149080            David Copperfield (Wordsworth Classics)    Charles Dickens
# 149081            David Copperfield (Wordsworth Classics)    Charles Dickens
# 149082            David Copperfield (Wordsworth Classics)    Charles Dickens
# 149083            David Copperfield (Wordsworth Classics)    Charles Dickens
# 149084            David Copperfield (Wordsworth Classics)    Charles Dickens
# 149085            David Copperfield (Wordsworth Classics)    Charles Dickens
# 149086            David Copperfield (Wordsworth Classics)    Charles Dickens
# 153182               David Copperfield (Penguin Classics)    Charles Dickens
# 153183               David Copperfield (Penguin Classics)    Charles Dickens
# 153184               David Copperfield (Penguin Classics)    Charles Dickens
# 153185               David Copperfield (Penguin Classics)    Charles Dickens
# 153186               David Copperfield (Penguin Classics)    Charles Dickens
# 153187               David Copperfield (Penguin Classics)    Charles Dickens
# 153244        David Copperfield's Tales of the Impossible  David Copperfield
# 153245        David Copperfield's Tales of the Impossible  David Copperfield
# 153246        David Copperfield's Tales of the Impossible  David Copperfield
# 173944              David Copperfield (David Copperfield)    Charles Dickens
# 201671    David Copperfield (Signet Classics (Paperback))    Charles Dickens
# 201672    David Copperfield (Signet Classics (Paperback))    Charles Dickens
# 201673    David Copperfield (Signet Classics (Paperback))    Charles Dickens
# 201674    David Copperfield (Signet Classics (Paperback))    Charles Dickens
# 211382                David Copperfield (Bantam Classics)    Charles Dickens
# 211383                David Copperfield (Bantam Classics)    Charles Dickens
# 241906        David Copperfield (Modern Library Classics)    Charles Dickens
# 241907        David Copperfield (Modern Library Classics)    Charles Dickens
# 241908        David Copperfield (Modern Library Classics)    Charles Dickens
# 262789       David Copperfield (Penguin Popular Classics)    Charles Dickens
# 262790       David Copperfield (Penguin Popular Classics)    Charles Dickens
# 262791       David Copperfield (Penguin Popular Classics)    Charles Dickens
# 268346        David Copperfield (Norton Critical Edition)    Charles Dickens
# 268347        David Copperfield (Norton Critical Edition)    Charles Dickens
# 286854                                  David Copperfield    Charles Dickens
# 286946  David Copperfield's Tales of the Impossible Vo...     Janet Berliner
# 286947  David Copperfield's Tales of the Impossible Vo...     Janet Berliner
# 288487           David Copperfield (Illustrated Classics)    Charles Dickens
# 312099    David Copperfield (Everyman Paperback Classics)    Charles Dickens
# 316872               David Copperfield (World's Classics)    Charles Dickens
# 319259                                  David Copperfield    Charles Dickens
# 321959             David Copperfield (Everyman's Library)    Charles Dickens
# 356275             David Copperfield's Beyond Imagination  David Copperfield
# 365540                                  David Copperfield    Charles Dickens
# 376953     David Copperfield (Great Illustrated Classics)    Charles Dickens
#
#                                    Publisher  UserID  TitleID
# 118262                         Penguin Books    2367   113562
# 118263                         Penguin Books   29423   113562
# 118264                         Penguin Books   60430   113562
# 127504               Oxford University Press    2719    25598
# 149078   NTC/Contemporary Publishing Company    2719    25602
# 149079   NTC/Contemporary Publishing Company    8384    25602
# 149080   NTC/Contemporary Publishing Company   31752    25602
# 149081   NTC/Contemporary Publishing Company   35507    25602
# 149082   NTC/Contemporary Publishing Company   45309    25602
# 149083   NTC/Contemporary Publishing Company   53558    25602
# 149084   NTC/Contemporary Publishing Company   58448    25602
# 149085   NTC/Contemporary Publishing Company   59472    25602
# 149086   NTC/Contemporary Publishing Company   64278    25602
# 153182                         Penguin Books    2816    25599
# 153183                         Penguin Books    3551    25599
# 153184                         Penguin Books   16347    25599
# 153185                         Penguin Books   39133    25599
# 153186                         Penguin Books   43372    25599
# 153187                         Penguin Books   49274    25599
# 153244                         Harpercollins    2829    25605
# 153245                         Harpercollins   23466    25605
# 153246                         Harpercollins   48826    25605
# 173944                             Tor Books    4193    25591
# 201671                       Signet Classics    7172    25601
# 201672                       Signet Classics   53433    25601
# 201673                       Signet Classics   54481    25601
# 201674                       Signet Classics   65964    25601
# 211382                                Bantam    8102    25590
# 211383                                Bantam   56999    25590
# 241906                        Modern Library   13040    25596
# 241907                        Modern Library   30603    25596
# 241908                        Modern Library   46279    25596
# 262789                     Penguin Books Ltd   17434    25600
# 262790                     Penguin Books Ltd   26428    25600
# 262791                     Penguin Books Ltd   54200    25600
# 268346            W. W. Norton &amp; Company   18757    25597
# 268347            W. W. Norton &amp; Company   33646    25597
# 286854                           Signet Book   23310    25589
# 286946                                   Eos   23330    25606
# 286947                                   Eos   54702    25606
# 288487                               Landoll   23657    25595
# 312099           Everyman Paperback Classics   29788    25592
# 316872               Oxford University Press   31656    25603
# 319259                     Pocket Books (Mm)   32666    25589
# 321959  Unknown Publisher - Being Researched   33727    25593
# 356275    Harper Mass Market Paperbacks (Mm)   49058    25604
# 365540                          Bantam Books   54948    25589
# 376953              Playmore Inc. Publishers   62164    25594

# %%
user_id = 10089
print('Rating buku dari user :')
rating_user[rating_user['UserID'].eq(user_id)]
# Out:
# Rating buku dari user :
#               ISBN  Book-Rating  \
# 27341   0385498802            8
# 44787   2253140872            9
# 51924   2070375161            5
# 89670   0061073628            9
# 167376  0140481346            7
# 225892  0060512377            7
# 225896  0061058262            7
# 225898  0345417127           10
# 225899  0425157415            8
# 225900  225303598X            8
# 225903  2266071106            5
#
#                                            Book-Title            Book-Author  \
# 27341                             Bee Season: A Novel          Myla Goldberg
# 44787                               L'Ecume Des Jours             Boris Vian
# 51924                            La Ferme Des Animaux          George Orwell
# 89670                   A Night Without Armor : Poems                  Jewel
# 167376                            Death of A Salesman          Arthur Miller
# 225892                       Does She or Doesn't She?          Alisa Kwitney
# 225896      The Crow: Clash by Night (The Crow, No 3)        Chet Williamson
# 225898  The Crow: Shattered Lives &amp; Broken Dreams              J. O'Barr
# 225899                       Vampires, Wine and Roses  John Richard Stephens
# 225900                            L'histoire sans fin                Ende M.
# 225903              DerniÃ?Â¨res nouvelles de Dracula       Kevin J Anderson
#
#                        Publisher  UserID  TitleID
# 27341     Anchor Books/Doubleday   10089    12078
# 44787            Distribooks Inc   10089    56579
# 51924           Gallimard French   10089    57282
# 89670         Perennial Currents   10089     3036
# 167376       Penguin USA (Paper)   10089    26496
# 225892                Avon Trade   10089    30136
# 225896        Perennial Currents   10089   102531
# 225898             Del Rey Books   10089   102533
# 225899  Berkley Publishing Group   10089   127583
# 225900                       LGF   10089    56736
# 225903                    Pocket   10089    27675

# %%
print('Rekomendasi buku yang mungkin disukai user')
user_recommendation(user_id)
# Out:
# Rekomendasi buku yang mungkin disukai user
#               ISBN                                         Book-Title  \
# 357860  0373871430            Husband To Hold (Love Inspired, No 136)
# 382316  0970583605  Richer Than King Tut : The Mental Game of Weal...
# 235661  8432043753  Como Cazar a UN Naturalista Aficionado/How to ...
# 355120  0671700278  DEEP SECRETS: NANCY DREW FILES #50 (A SUMMER O...
# 382995  3442453852                                          Hurenkind
# 67761   0906138213  Lent and Eastertide (In Conversation with God,...
# 316461  0590137743                     Fade to Black (Point Crime S.)
# 224922  0812575733                                   Border Crossings
# 128797  0340784989        You're a Disgrace, Daisy (Definitely Daisy)
# 288166  0316848727                                  New England Wilds
#
#               Book-Author                    Publisher  Estimate_Score
# 357860   Cheryl Wolverton                 Steeple Hill        8.111522
# 382316         Lela Hayes  World Prosperity Publishing        8.083559
# 235661     Gerald Durrell             Planeta Pub Corp        8.079724
# 355120      Carolyn Keene                  Simon Pulse        8.076270
# 382995     Christine Gran              Distribooks Inc        8.074864
# 67761   Francis Fernandez     Scepter Publishers, Inc.        8.066238
# 316461      Stan Nicholls             Scholastic Point        8.060410
# 224922   Carole Bellacera                  Forge Books        8.055868
# 128797     Jenny Oldfield      Hodder Children's Books        8.051003
# 288166       Ogden Tanner   Little Brown &amp; Company        8.049062
